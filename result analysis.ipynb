# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Assuming you have accuracy and loss history for each model
# Replace these lists with your actual data
densenet121_history = {
   'accuracy': [0.63, 0.77, 0.79, 0.81, 0.82], 'val_accuracy': [0.80, 0.80, 0.81, 0.82, 0.78], 'loss': [0.99, 0.60, 0.53, 0.49, 0.48], 'val_loss': [0.52, 0.58, 0.49, 0.44, 0.50]
}

densenet169_history = {
   'accuracy': [0.56, 0,76, 0.80, 0.81, 0.83], 'val_accuracy': [0.72, 0.77, 0.81, 0.77, 0.79], 'loss': [1.08, 0.62, 0.51, 0.47, 0.43], 'val_loss': [0.65, 0.56, 0.52, 0.59, 0.53]
}

inceptionv3_history = {
   'accuracy': [0.55, 0.72, 0.75, 0.78, 0.79], 'val_accuracy': [0.62, 0.68, 0.68, 0.72, 0.71], 'loss': [1.18, 0.73, 0.65, 0.57, 0.52], 'val_loss': [0.93, 0.82, 0.80, 0.76, 0.80]
}

# Plotting accuracy
plt.figure(figsize=(14, 6))
plt.plot(densenet121_history['accuracy'], label='DenseNet121 Training Accuracy')
plt.plot(densenet121_history['val_accuracy'], label='DenseNet121 Validation Accuracy')
plt.plot(densenet169_history['accuracy'], label='DenseNet169 Training Accuracy')
plt.plot(densenet169_history['val_accuracy'], label='DenseNet169 Validation Accuracy')
plt.plot(inceptionv3_history['accuracy'], label='InceptionV3 Training Accuracy')
plt.plot(inceptionv3_history['val_accuracy'], label='InceptionV3 Validation Accuracy')
plt.title('Training and Validation Accuracy Comparison')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Plotting loss
plt.figure(figsize=(14, 6))
plt.plot(densenet121_history['loss'], label='DenseNet121 Training Loss')
plt.plot(densenet121_history['val_loss'], label='DenseNet121 Validation Loss')
plt.plot(densenet169_history['loss'], label='DenseNet169 Training Loss')
plt.plot(densenet169_history['val_loss'], label='DenseNet169 Validation Loss')
plt.plot(inceptionv3_history['loss'], label='InceptionV3 Training Loss')
plt.plot(inceptionv3_history['val_loss'], label='InceptionV3 Validation Loss')
plt.title('Training and Validation Loss Comparison')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data (replace with your actual data)
model_histories = {
    'DenseNet121': {'accuracy': [0.63, 0.77, 0.79, 0.81, 0.82], 'val_accuracy': [0.80, 0.80, 0.81, 0.82, 0.78], 'loss': [0.99, 0.60, 0.53, 0.49, 0.48], 'val_loss': [0.52, 0.58, 0.49, 0.44, 0.50]},
    'DenseNet169': {'accuracy': [0.56, 0,76, 0.80, 0.81, 0.83], 'val_accuracy': [0.72, 0.77, 0.81, 0.77, 0.79], 'loss': [1.08, 0.62, 0.51, 0.47, 0.43], 'val_loss': [0.65, 0.56, 0.52, 0.59, 0.53]},
    'InceptionV3': {'accuracy': [0.55, 0.72, 0.75, 0.78, 0.79], 'val_accuracy': [0.62, 0.68, 0.68, 0.72, 0.71], 'loss': [1.18, 0.73, 0.65, 0.57, 0.52], 'val_loss': [0.93, 0.82, 0.80, 0.76, 0.80]},
}

# Plot Accuracy
plt.figure(figsize=(14, 6))
for model_name, history in model_histories.items():
    plt.plot(history['accuracy'], label=f'{model_name} Training Accuracy')
    plt.plot(history['val_accuracy'], label=f'{model_name} Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Plot Loss
plt.figure(figsize=(14, 6))
for model_name, history in model_histories.items():
    plt.plot(history['loss'], label=f'{model_name} Training Loss')
    plt.plot(history['val_loss'], label=f'{model_name} Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Updated classification reports
classification_reports = {
    'DenseNet121': {'Mild': {'precision': 0.88, 'recall': 0.53, 'f1-score': 0.66, 'support': 40},
                     'Moderate': {'precision': 0.68, 'recall': 0.79, 'f1-score': 0.73, 'support': 103},
                     'No_DR': {'precision': 0.94, 'recall': 0.99, 'f1-score': 0.97, 'support': 185},
                     'Proliferate_DR': {'precision': 0.38, 'recall': 0.36, 'f1-score': 0.37, 'support': 25},
                     'Severe': {'precision': 0.00, 'recall': 0.00, 'f1-score': 0.00, 'support': 14}},
    'DenseNet169': {'Mild': {'precision': 0.76, 'recall': 0.84, 'f1-score': 0.80, 'support': 87},
                     'Moderate': {'precision': 0.74, 'recall': 0.78, 'f1-score': 0.76, 'support': 101},
                     'No_DR': {'precision': 0.94, 'recall': 0.95, 'f1-score': 0.94, 'support': 208},
                     'Proliferate_DR': {'precision': 0.64, 'recall': 0.36, 'f1-score': 0.46, 'support': 50},
                     'Severe': {'precision': 0.58, 'recall': 0.66, 'f1-score': 0.62, 'support': 47}},
    'InceptionV3': {'Mild': {'precision': 0.53, 'recall': 0.24, 'f1-score': 0.33, 'support': 38},
                     'Moderate': {'precision': 0.55, 'recall': 0.86, 'f1-score': 0.67, 'support': 96},
                     'No_DR': {'precision': 0.93, 'recall': 0.92, 'f1-score': 0.92, 'support': 209},
                     'Proliferate_DR': {'precision': 0.61, 'recall': 0.41, 'f1-score': 0.49, 'support': 54},
                     'Severe': {'precision': 0.64, 'recall': 0.45, 'f1-score': 0.53, 'support': 51}},
}

# Prepare data for DataFrame
data = []
for model, metrics in classification_reports.items():
    for cls, scores in metrics.items():
        for metric, value in scores.items():
            if metric != 'support':  # Exclude 'support' from plotting
                data.append({'Model': model, 'Class': cls, 'Metric': metric, 'Value': value})

# Convert to DataFrame
reports_df = pd.DataFrame(data)

# Plot precision, recall, and f1-score
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

metrics = ['precision', 'recall', 'f1-score']
titles = ['Precision Comparison', 'Recall Comparison', 'F1-Score Comparison']

for i, metric in enumerate(metrics):
    sns.barplot(x='Class', y='Value', hue='Model', data=reports_df[reports_df['Metric'] == metric], ax=axes[i])
    axes[i].set_title(titles[i])
    axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)
    axes[i].set_ylabel('Value')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Updated classification reports
classification_reports = {
    'DenseNet121': {'Mild': {'precision': 0.88, 'recall': 0.53, 'f1-score': 0.66, 'support': 40},
                     'Moderate': {'precision': 0.68, 'recall': 0.79, 'f1-score': 0.73, 'support': 103},
                     'No_DR': {'precision': 0.94, 'recall': 0.99, 'f1-score': 0.97, 'support': 185},
                     'Proliferate_DR': {'precision': 0.38, 'recall': 0.36, 'f1-score': 0.37, 'support': 25},
                     'Severe': {'precision': 0.00, 'recall': 0.00, 'f1-score': 0.00, 'support': 14}},
    'DenseNet169': {'Mild': {'precision': 0.76, 'recall': 0.84, 'f1-score': 0.80, 'support': 87},
                     'Moderate': {'precision': 0.74, 'recall': 0.78, 'f1-score': 0.76, 'support': 101},
                     'No_DR': {'precision': 0.94, 'recall': 0.95, 'f1-score': 0.94, 'support': 208},
                     'Proliferate_DR': {'precision': 0.64, 'recall': 0.36, 'f1-score': 0.46, 'support': 50},
                     'Severe': {'precision': 0.58, 'recall': 0.66, 'f1-score': 0.62, 'support': 47}},
    'InceptionV3': {'Mild': {'precision': 0.53, 'recall': 0.24, 'f1-score': 0.33, 'support': 38},
                     'Moderate': {'precision': 0.55, 'recall': 0.86, 'f1-score': 0.67, 'support': 96},
                     'No_DR': {'precision': 0.93, 'recall': 0.92, 'f1-score': 0.92, 'support': 209},
                     'Proliferate_DR': {'precision': 0.61, 'recall': 0.41, 'f1-score': 0.49, 'support': 54},
                     'Severe': {'precision': 0.64, 'recall': 0.45, 'f1-score': 0.53, 'support': 51}},
}

# Prepare data for DataFrame
data = []
for model, metrics in classification_reports.items():
    for cls, scores in metrics.items():
        for metric, value in scores.items():
            if metric != 'support':  # Exclude 'support' from plotting
                data.append({'Model': model, 'Class': cls, 'Metric': metric, 'Value': value})

# Convert to DataFrame
reports_df = pd.DataFrame(data)

# Define metrics and titles
metrics = ['precision', 'recall', 'f1-score']
titles = ['Precision Comparison', 'Recall Comparison', 'F1-Score Comparison']

# Plot each metric separately
for metric, title in zip(metrics, titles):
    plt.figure(figsize=(10, 6))
    sns.barplot(x='Class', y='Value', hue='Model', data=reports_df[reports_df['Metric'] == metric])
    plt.title(title)
    plt.xticks(rotation=45)
    plt.ylabel('Value')
    plt.tight_layout()
    plt.show()
